# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_json('AllPrintings.json')

# %%
dfc = pd.read_csv('cards.csv', low_memory=False)

# %%
dfc.head(5)
# Out:
#    index  id             artist asciiName availability borderColor  \
# 0      0   1       Pete Venters       NaN   mtgo,paper       black
# 1      1   2        Volkan Baǵa       NaN   mtgo,paper       black
# 2      2   3       Justin Sweet       NaN   mtgo,paper       black
# 3      3   4  Matthew D. Wilson       NaN   mtgo,paper       black
# 4      4   5       Rebecca Guay       NaN   mtgo,paper       black
#
#    cardKingdomFoilId  cardKingdomId colorIdentity colorIndicator  ...  \
# 0                NaN       122719.0             W            NaN  ...
# 1                NaN       122720.0             W            NaN  ...
# 2                NaN       122725.0             W            NaN  ...
# 3           123094.0       122726.0             W            NaN  ...
# 4           123095.0       122727.0             W            NaN  ...
#
#        subtypes  supertypes tcgplayerProductId  \
# 0  Human,Cleric         NaN            15032.0
# ...

# %%
dfc = dfc.drop(['asciiName', 'availability', 'cardKingdomFoilId', 'cardKingdomId'], axis=1)

# %%
dfc.columns
# Out:
# Index(['index', 'id', 'artist', 'borderColor', 'colorIdentity',
#        'colorIndicator', 'colors', 'convertedManaCost', 'duelDeck',
#        'edhrecRank', 'faceConvertedManaCost', 'faceName', 'flavorName',
#        'flavorText', 'frameEffects', 'frameVersion', 'hand',
#        'hasAlternativeDeckLimit', 'hasContentWarning', 'hasFoil', 'hasNonFoil',
#        'isAlternative', 'isFullArt', 'isOnlineOnly', 'isOversized', 'isPromo',
#        'isReprint', 'isReserved', 'isStarter', 'isStorySpotlight',
#        'isTextless', 'isTimeshifted', 'keywords', 'layout', 'leadershipSkills',
#        'life', 'loyalty', 'manaCost', 'mcmId', 'mcmMetaId', 'mtgArenaId',
#        'mtgjsonV4Id', 'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'number',
#        'originalReleaseDate', 'originalText', 'originalType', 'otherFaceIds',
#        'power', 'printings', 'promoTypes', 'purchaseUrls', 'rarity',
#        'scryfallId', 'scryfallIllustrationId', 'scryfallOracleId', 'setCode',
# ...

# %%
dfc.head(5)
# Out:
#    index  id             artist borderColor colorIdentity colorIndicator  \
# 0      0   1       Pete Venters       black             W            NaN
# 1      1   2        Volkan Baǵa       black             W            NaN
# 2      2   3       Justin Sweet       black             W            NaN
# 3      3   4  Matthew D. Wilson       black             W            NaN
# 4      4   5       Rebecca Guay       black             W            NaN
#
#   colors  convertedManaCost duelDeck  edhrecRank  ...      subtypes  \
# 0      W                7.0      NaN     15754.0  ...  Human,Cleric
# 1      W                5.0      NaN     12792.0  ...         Angel
# 2      W                4.0      NaN     10820.0  ...  Bird,Soldier
# 3      W                4.0      NaN     12829.0  ...   Human,Rebel
# 4      W                1.0      NaN      4057.0  ...           NaN
#
#   supertypes tcgplayerProductId  \
# 0        NaN            15032.0
# 1        NaN            15033.0
# ...

# %%
dfc = dfc.drop(['index', 'id', 'colorIndicator', 'duelDeck', 'edhrecRank'], axis=1)

# %%
dfc.head(5)
# Out:
#               artist borderColor colorIdentity colors  convertedManaCost  \
# 0       Pete Venters       black             W      W                7.0
# 1        Volkan Baǵa       black             W      W                5.0
# 2       Justin Sweet       black             W      W                4.0
# 3  Matthew D. Wilson       black             W      W                4.0
# 4       Rebecca Guay       black             W      W                1.0
#
#    faceConvertedManaCost faceName flavorName  \
# 0                    NaN      NaN        NaN
# 1                    NaN      NaN        NaN
# 2                    NaN      NaN        NaN
# 3                    NaN      NaN        NaN
# 4                    NaN      NaN        NaN
#
#                                           flavorText frameEffects  ...  \
# 0                                                NaN          NaN  ...
# 1          Every tear shed is a drop of immortality.          NaN  ...
# ...

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'faceConvertedManaCost', 'faceName', 'flavorName', 'flavorText',
#        'frameEffects', 'frameVersion', 'hand', 'hasAlternativeDeckLimit',
#        'hasContentWarning', 'hasFoil', 'hasNonFoil', 'isAlternative',
#        'isFullArt', 'isOnlineOnly', 'isOversized', 'isPromo', 'isReprint',
#        'isReserved', 'isStarter', 'isStorySpotlight', 'isTextless',
#        'isTimeshifted', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'mcmId', 'mcmMetaId', 'mtgArenaId',
#        'mtgjsonV4Id', 'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'number',
#        'originalReleaseDate', 'originalText', 'originalType', 'otherFaceIds',
#        'power', 'printings', 'promoTypes', 'purchaseUrls', 'rarity',
#        'scryfallId', 'scryfallIllustrationId', 'scryfallOracleId', 'setCode',
#        'side', 'subtypes', 'supertypes', 'tcgplayerProductId', 'text',
# ...

# %%
dfc = dfc.drop(['faceConvertedManaCost', 'faceName', 'flavorName', 'frameEffects'], axis=1)

# %%
dfc.head(1)
# Out:
#          artist borderColor colorIdentity colors  convertedManaCost  \
# 0  Pete Venters       black             W      W                7.0
#
#   flavorText frameVersion  hand  hasAlternativeDeckLimit  hasContentWarning  \
# 0        NaN         2003   NaN                        0                  0
#
#    ...      subtypes  supertypes  tcgplayerProductId  \
# 0  ...  Human,Cleric         NaN             15032.0
#
#                                                 text  toughness  \
# 0  First strike (This creature deals combat damag...          4
#
#                       type     types                                  uuid  \
# 0  Creature — Human Cleric  Creature  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
#
#                              variations  watermark
# 0  b7c19924-b4bf-56fc-aa73-f586e940bd42        NaN
#
# [1 rows x 62 columns]

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'frameVersion', 'hand', 'hasAlternativeDeckLimit',
#        'hasContentWarning', 'hasFoil', 'hasNonFoil', 'isAlternative',
#        'isFullArt', 'isOnlineOnly', 'isOversized', 'isPromo', 'isReprint',
#        'isReserved', 'isStarter', 'isStorySpotlight', 'isTextless',
#        'isTimeshifted', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'mcmId', 'mcmMetaId', 'mtgArenaId',
#        'mtgjsonV4Id', 'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'number',
#        'originalReleaseDate', 'originalText', 'originalType', 'otherFaceIds',
#        'power', 'printings', 'promoTypes', 'purchaseUrls', 'rarity',
#        'scryfallId', 'scryfallIllustrationId', 'scryfallOracleId', 'setCode',
#        'side', 'subtypes', 'supertypes', 'tcgplayerProductId', 'text',
#        'toughness', 'type', 'types', 'uuid', 'variations', 'watermark'],
# ...

# %%
dfc = dfc.drop(['frameVersion', 'hand', 'hasAlternativeDeckLimit', 'hasContentWarning'], axis=1)

# %%
dfc.head(1)
# Out:
#          artist borderColor colorIdentity colors  convertedManaCost  \
# 0  Pete Venters       black             W      W                7.0
#
#   flavorText  hasFoil  hasNonFoil  isAlternative  isFullArt  ...  \
# 0        NaN        0           1              0          0  ...
#
#        subtypes  supertypes  tcgplayerProductId  \
# 0  Human,Cleric         NaN             15032.0
#
#                                                 text  toughness  \
# 0  First strike (This creature deals combat damag...          4
#
#                       type     types                                  uuid  \
# 0  Creature — Human Cleric  Creature  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
#
#                              variations watermark
# 0  b7c19924-b4bf-56fc-aa73-f586e940bd42       NaN
#
# [1 rows x 58 columns]

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'hasFoil', 'hasNonFoil', 'isAlternative', 'isFullArt',
#        'isOnlineOnly', 'isOversized', 'isPromo', 'isReprint', 'isReserved',
#        'isStarter', 'isStorySpotlight', 'isTextless', 'isTimeshifted',
#        'keywords', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'mcmId', 'mcmMetaId', 'mtgArenaId', 'mtgjsonV4Id', 'mtgoFoilId',
#        'mtgoId', 'multiverseId', 'name', 'number', 'originalReleaseDate',
#        'originalText', 'originalType', 'otherFaceIds', 'power', 'printings',
#        'promoTypes', 'purchaseUrls', 'rarity', 'scryfallId',
#        'scryfallIllustrationId', 'scryfallOracleId', 'setCode', 'side',
#        'subtypes', 'supertypes', 'tcgplayerProductId', 'text', 'toughness',
#        'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
dfc = dfc.drop(['hasFoil', 'hasNonFoil', 'isAlternative', 'isFullArt', 'isOnlineOnly', 'isOversized', 'isPromo', 'isReprint', 'isReserved', 'isStarter', 'isStorySpotlight'], axis=1)

# %%
dfc.head(5)
# Out:
#               artist borderColor colorIdentity colors  convertedManaCost  \
# 0       Pete Venters       black             W      W                7.0
# 1        Volkan Baǵa       black             W      W                5.0
# 2       Justin Sweet       black             W      W                4.0
# 3  Matthew D. Wilson       black             W      W                4.0
# 4       Rebecca Guay       black             W      W                1.0
#
#                                           flavorText  isTextless  \
# 0                                                NaN           0
# 1          Every tear shed is a drop of immortality.           0
# 2                                                NaN           0
# 3  The perfect antidote for a tightly packed form...           0
# 4  Life is measured in inches. To a healer, every...           0
#
#    isTimeshifted      keywords  layout  ...      subtypes  supertypes  \
# ...

# %%
dfc = dfc.drop(['isTextless', 'isTimeshifted'], axis=1)

# %%
dfc.head(5)
# Out:
#               artist borderColor colorIdentity colors  convertedManaCost  \
# 0       Pete Venters       black             W      W                7.0
# 1        Volkan Baǵa       black             W      W                5.0
# 2       Justin Sweet       black             W      W                4.0
# 3  Matthew D. Wilson       black             W      W                4.0
# 4       Rebecca Guay       black             W      W                1.0
#
#                                           flavorText      keywords  layout  \
# 0                                                NaN  First strike  normal
# 1          Every tear shed is a drop of immortality.        Flying  normal
# 2                                                NaN        Flying  normal
# 3  The perfect antidote for a tightly packed form...           NaN  normal
# 4  Life is measured in inches. To a healer, every...           NaN  normal
#
# ...

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'mcmId', 'mcmMetaId', 'mtgArenaId',
#        'mtgjsonV4Id', 'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'number',
#        'originalReleaseDate', 'originalText', 'originalType', 'otherFaceIds',
#        'power', 'printings', 'promoTypes', 'purchaseUrls', 'rarity',
#        'scryfallId', 'scryfallIllustrationId', 'scryfallOracleId', 'setCode',
#        'side', 'subtypes', 'supertypes', 'tcgplayerProductId', 'text',
#        'toughness', 'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
dfc = dfc.drop(['mcmId', 'mcmMetaId', 'mtgArenaId',
       'mtgjsonV4Id', 'mtgoFoilId', 'mtgoId', 'multiverseId'], axis=1)

# %%
dfc.head(5)
# Out:
#               artist borderColor colorIdentity colors  convertedManaCost  \
# 0       Pete Venters       black             W      W                7.0
# 1        Volkan Baǵa       black             W      W                5.0
# 2       Justin Sweet       black             W      W                4.0
# 3  Matthew D. Wilson       black             W      W                4.0
# 4       Rebecca Guay       black             W      W                1.0
#
#                                           flavorText      keywords  layout  \
# 0                                                NaN  First strike  normal
# 1          Every tear shed is a drop of immortality.        Flying  normal
# 2                                                NaN        Flying  normal
# 3  The perfect antidote for a tightly packed form...           NaN  normal
# 4  Life is measured in inches. To a healer, every...           NaN  normal
#
# ...

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'name', 'number', 'originalReleaseDate',
#        'originalText', 'originalType', 'otherFaceIds', 'power', 'printings',
#        'promoTypes', 'purchaseUrls', 'rarity', 'scryfallId',
#        'scryfallIllustrationId', 'scryfallOracleId', 'setCode', 'side',
#        'subtypes', 'supertypes', 'tcgplayerProductId', 'text', 'toughness',
#        'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
dfc[['printings',
       'promoTypes', 'purchaseUrls', 'rarity', 'scryfallId',
       'scryfallIllustrationId', 'scryfallOracleId', 'setCode']]
# Out:
#                                                printings promoTypes  \
# 0                                            10E,JUD,UMA        NaN
# 1      10E,8ED,9ED,DDC,DVD,IMA,INV,JMP,MB1,P02,PS11,P...        NaN
# 2                                        10E,8ED,9ED,ODY        NaN
# 3                                            10E,9ED,MMQ        NaN
# 4                                            10E,STH,TPR        NaN
# ...                                                  ...        ...
# 56280                   C14,C17,C18,CMR,DDM,PS11,ZEN,ZNR  promopack
# 56281                                                ZNR  promopack
# 56282                                                ZNR  promopack
# 56283                                                ZNR  promopack
# 56284                                                ZNR  promopack
#
#                                             purchaseUrls    rarity  \
# 0      {'cardKingdom': 'https://mtgjson.com/links/9fb...  uncommon
# ...

# %%
dfc = dfc.drop(['number', 'originalReleaseDate', 'otherFaceIds'], axis=1)

# %%
dfc[['printings',
       'promoTypes', 'purchaseUrls', 'rarity', 'scryfallId',
       'scryfallIllustrationId', 'scryfallOracleId', 'setCode']]
# Out:
#                                                printings promoTypes  \
# 0                                            10E,JUD,UMA        NaN
# 1      10E,8ED,9ED,DDC,DVD,IMA,INV,JMP,MB1,P02,PS11,P...        NaN
# 2                                        10E,8ED,9ED,ODY        NaN
# 3                                            10E,9ED,MMQ        NaN
# 4                                            10E,STH,TPR        NaN
# ...                                                  ...        ...
# 56280                   C14,C17,C18,CMR,DDM,PS11,ZEN,ZNR  promopack
# 56281                                                ZNR  promopack
# 56282                                                ZNR  promopack
# 56283                                                ZNR  promopack
# 56284                                                ZNR  promopack
#
#                                             purchaseUrls    rarity  \
# 0      {'cardKingdom': 'https://mtgjson.com/links/9fb...  uncommon
# ...

# %%
dfc = dfc.drop(['printings',
       'promoTypes', 'purchaseUrls', 'scryfallId',
       'scryfallIllustrationId', 'scryfallOracleId', 'setCode'], axis=1)

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'name', 'originalText', 'originalType', 'power',
#        'rarity', 'side', 'subtypes', 'supertypes', 'tcgplayerProductId',
#        'text', 'toughness', 'type', 'types', 'uuid', 'variations',
#        'watermark'],
#       dtype='object')

# %%
dfc[['side', 'subtypes', 'supertypes', 'tcgplayerProductId', 'text', 'toughness']]
# Out:
#       side       subtypes supertypes  tcgplayerProductId  \
# 0      NaN   Human,Cleric        NaN             15032.0
# 1      NaN          Angel        NaN             15033.0
# 2      NaN   Bird,Soldier        NaN             15045.0
# 3      NaN    Human,Rebel        NaN             15048.0
# 4      NaN            NaN        NaN             15049.0
# ...    ...            ...        ...                 ...
# 56280  NaN            NaN        NaN            222847.0
# 56281  NaN            NaN        NaN            222848.0
# 56282  NaN            NaN        NaN            222850.0
# 56283  NaN            NaN        NaN            222851.0
# 56284  NaN  Human,Warrior        NaN            222853.0
#
#                                                     text toughness
# 0      First strike (This creature deals combat damag...         4
# 1      Flying\nWhen Angel of Mercy enters the battlef...         3
# 2      Flying (This creature can't be blocked except ...         2
# ...

# %%
dfc = dfc.drop(['side', 'tcgplayerProductId'], axis=1)

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'name', 'originalText', 'originalType', 'power',
#        'rarity', 'subtypes', 'supertypes', 'text', 'toughness', 'type',
#        'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
dfc[['type', 'types', 'uuid', 'variations', 'watermark']]
# Out:
#                            type     types  \
# 0       Creature — Human Cleric  Creature
# 1              Creature — Angel  Creature
# 2       Creature — Bird Soldier  Creature
# 3        Creature — Human Rebel  Creature
# 4                       Instant   Instant
# ...                         ...       ...
# 56280                   Instant   Instant
# 56281                   Sorcery   Sorcery
# 56282                   Sorcery   Sorcery
# 56283                   Instant   Instant
# 56284  Creature — Human Warrior  Creature
#
#                                        uuid  \
# 0      5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# 1      57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 2      8ac972b5-9f6e-5cc8-91c3-b9a40a98232e
# 3      a69b404f-144a-5317-b10e-7d9dce135b24
# 4      6d268c95-c176-5766-9a46-c14f739aba1c
# ...                                     ...
# 56280  3f492516-7767-5ed7-a1d4-e3f7c06aee2f
# 56281  3f9a0369-5fe7-5aee-85fe-3cfaacd275af
# 56282  97577e9e-69a9-5a8b-9c24-a72703790046
# ...

# %%
dfc = dfc.drop(['uuid', 'variations', 'watermark'], axis=1)

# %%
dfc.head(5)
# Out:
#               artist borderColor colorIdentity colors  convertedManaCost  \
# 0       Pete Venters       black             W      W                7.0
# 1        Volkan Baǵa       black             W      W                5.0
# 2       Justin Sweet       black             W      W                4.0
# 3  Matthew D. Wilson       black             W      W                4.0
# 4       Rebecca Guay       black             W      W                1.0
#
#                                           flavorText      keywords  layout  \
# 0                                                NaN  First strike  normal
# 1          Every tear shed is a drop of immortality.        Flying  normal
# 2                                                NaN        Flying  normal
# 3  The perfect antidote for a tightly packed form...           NaN  normal
# 4  Life is measured in inches. To a healer, every...           NaN  normal
#
#   leadershipSkills  life  ...  \
# 0              NaN   NaN  ...
# ...

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost',
#        'flavorText', 'keywords', 'layout', 'leadershipSkills', 'life',
#        'loyalty', 'manaCost', 'name', 'originalText', 'originalType', 'power',
#        'rarity', 'subtypes', 'supertypes', 'text', 'toughness', 'type',
#        'types'],
#       dtype='object')

# %%
dfc[['manaCost']]
# Out:
#         manaCost
# 0      {5}{W}{W}
# 1         {4}{W}
# 2         {3}{W}
# 3         {3}{W}
# 4            {W}
# ...          ...
# 56280     {1}{U}
# 56281        {B}
# 56282     {1}{R}
# 56283     {2}{G}
# 56284  {1}{R}{W}
#
# [56285 rows x 1 columns]

# %%
dfc = dfc.drop('convertedManaCost', axis=1)

# %%
dfc.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'flavorText',
#        'keywords', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'name', 'originalText', 'originalType', 'power', 'rarity', 'subtypes',
#        'supertypes', 'text', 'toughness', 'type', 'types'],
#       dtype='object')

# %%
dfc.to_csv('cards_treated.csv', index=False)

# %%
dft = pd.read_csv('cards_treated.csv')

# %%
dft.columns
# Out:
# Index(['artist', 'borderColor', 'colorIdentity', 'colors', 'flavorText',
#        'keywords', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'name', 'originalText', 'originalType', 'power', 'rarity', 'subtypes',
#        'supertypes', 'text', 'toughness', 'type', 'types'],
#       dtype='object')

# %%
dft.head(5)
# Out:
#               artist borderColor colorIdentity colors  \
# 0       Pete Venters       black             W      W
# 1        Volkan Baǵa       black             W      W
# 2       Justin Sweet       black             W      W
# 3  Matthew D. Wilson       black             W      W
# 4       Rebecca Guay       black             W      W
#
#                                           flavorText      keywords  layout  \
# 0                                                NaN  First strike  normal
# 1          Every tear shed is a drop of immortality.        Flying  normal
# 2                                                NaN        Flying  normal
# 3  The perfect antidote for a tightly packed form...           NaN  normal
# 4  Life is measured in inches. To a healer, every...           NaN  normal
#
#   leadershipSkills  life loyalty  ...  \
# 0              NaN   NaN     NaN  ...
# 1              NaN   NaN     NaN  ...
# 2              NaN   NaN     NaN  ...
# ...

# %%
len(dft)
# Out:
# 56285

# %%
e
